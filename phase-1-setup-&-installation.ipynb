# %% [markdown]
# # Seaborn install and setup

# %% [markdown]
# ### What is Seaborn?
#     Seaborn is a data visualization library built on top of matplotlib and closely integrated with pandas data structure in python.

# %% [markdown]
# ### Seaborn Graphs
#         1. Scatter Plot
#         2. Customizing with Matplotlib
#         3. Box Plot
#         4. Violin Plot
#         5. Swarm Plot
#         6. Overlaying Plots
#         7. Heatmap
#         8. Histogram
#         9. Bar Plot
#         10. Factor Plot
#         11. Density Plot
#         12. Joint Distribution Plot

# %% [markdown]
# ### Dependency of Seaborn
#     1. Python
#     2. Numpy
#     3. Matplotlib
#     4. Pandas
#     5. SciPy

# %% [markdown]
# ### Installation Seaborn
#     1. pip install seaborn
#     2. Conda install seaborn        (optional this package and then work in anaconda this use package)
#     3. pip install matplotlib

# %% [markdown]
# ### Importing Matplotlib
#     1. import matplotlib.pyplot as pyplot
#     2. from matplotlib import pyplot as pyplot
#     3. import seaborn as sns
